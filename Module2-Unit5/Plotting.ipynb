# %% [markdown]
# ## Assignment 1.5 Matplotlib
# Matplotlib is a Python data visualization library which produces publication quality figures in a variety of hardcopy formats and interactive environments across platforms.
#
# See: [Official Documentation](https://matplotlib.org/).
#
# We also need to use one of the main feature of IPython kernel to show rich output for [plotting](https://ipython.readthedocs.io/en/stable/interactive/plotting.html).
#
# Pandas also provides many [visualisation tools](https://pandas.pydata.org/pandas-docs/stable/visualization.html)  to plot data.

# %%
# Import all the required library 
# YOUR CODE HERE
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Please go through the [Matplotlib Tutorial](https://matplotlib.org/tutorials/introductory/pyplot.html) and try out the functions
# - plot
# - subplot
# - scatter
# - bar

# %% [markdown]
# ## Diabetes Dataset
#
# The dataset consists of several medical predictor variables and one target variable, whether someone has diabetes or not.
#
# **Attribute details**:
#
# - preg: Number of times pregnant
# - plas: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# - pres: Diastolic blood pressure (mm Hg)
# - skin: Triceps skin fold thickness (mm)
# - test: 2-Hour serum insulin (mu U/ml)
# - mass: Body mass index (weight in kg/(height in m)^2)
# - pedi: Diabetes pedigree function
# - age: Age (years)
# - class: Class variable (0 or 1);

# %%
# load diabetes.csv to continue, use names list for the column names
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
# YOUR CODE HERE
data = pd.read_csv("diabetes.csv", header=None)
data.columns = names

# %%
data
# Out:
#      preg  plas  pres  skin  test  mass   pedi  age  class
# 0       6   148    72    35     0  33.6  0.627   50      1
# 1       1    85    66    29     0  26.6  0.351   31      0
# 2       8   183    64     0     0  23.3  0.672   32      1
# 3       1    89    66    23    94  28.1  0.167   21      0
# 4       0   137    40    35   168  43.1  2.288   33      1
# 5       5   116    74     0     0  25.6  0.201   30      0
# 6       3    78    50    32    88  31.0  0.248   26      1
# 7      10   115     0     0     0  35.3  0.134   29      0
# 8       2   197    70    45   543  30.5  0.158   53      1
# 9       8   125    96     0     0   0.0  0.232   54      1
# 10      4   110    92     0     0  37.6  0.191   30      0
# 11     10   168    74     0     0  38.0  0.537   34      1
# 12     10   139    80     0     0  27.1  1.441   57      0
# 13      1   189    60    23   846  30.1  0.398   59      1
# 14      5   166    72    19   175  25.8  0.587   51      1
# 15      7   100     0     0     0  30.0  0.484   32      1
# 16      0   118    84    47   230  45.8  0.551   31      1
# 17      7   107    74     0     0  29.6  0.254   31      1
# 18      1   103    30    38    83  43.3  0.183   33      0
# 19      1   115    70    30    96  34.6  0.529   32      1
# 20      3   126    88    41   235  39.3  0.704   27      0
# 21      8    99    84     0     0  35.4  0.388   50      0
# 22      7   196    90     0     0  39.8  0.451   41      1
# 23      9   119    80    35     0  29.0  0.263   29      1
# 24     11   143    94    33   146  36.6  0.254   51      1
# 25     10   125    70    26   115  31.1  0.205   41      1
# 26      7   147    76     0     0  39.4  0.257   43      1
# 27      1    97    66    15   140  23.2  0.487   22      0
# 28     13   145    82    19   110  22.2  0.245   57      0
# 29      5   117    92     0     0  34.1  0.337   38      0
# ..    ...   ...   ...   ...   ...   ...    ...  ...    ...
# 738     2    99    60    17   160  36.6  0.453   21      0
# 739     1   102    74     0     0  39.5  0.293   42      1
# 740    11   120    80    37   150  42.3  0.785   48      1
# 741     3   102    44    20    94  30.8  0.400   26      0
# 742     1   109    58    18   116  28.5  0.219   22      0
# 743     9   140    94     0     0  32.7  0.734   45      1
# 744    13   153    88    37   140  40.6  1.174   39      0
# 745    12   100    84    33   105  30.0  0.488   46      0
# 746     1   147    94    41     0  49.3  0.358   27      1
# 747     1    81    74    41    57  46.3  1.096   32      0
# 748     3   187    70    22   200  36.4  0.408   36      1
# 749     6   162    62     0     0  24.3  0.178   50      1
# 750     4   136    70     0     0  31.2  1.182   22      1
# 751     1   121    78    39    74  39.0  0.261   28      0
# 752     3   108    62    24     0  26.0  0.223   25      0
# 753     0   181    88    44   510  43.3  0.222   26      1
# 754     8   154    78    32     0  32.4  0.443   45      1
# 755     1   128    88    39   110  36.5  1.057   37      1
# 756     7   137    90    41     0  32.0  0.391   39      0
# 757     0   123    72     0     0  36.3  0.258   52      1
# 758     1   106    76     0     0  37.5  0.197   26      0
# 759     6   190    92     0     0  35.5  0.278   66      1
# 760     2    88    58    26    16  28.4  0.766   22      0
# 761     9   170    74    31     0  44.0  0.403   43      1
# 762     9    89    62     0     0  22.5  0.142   33      0
# 763    10   101    76    48   180  32.9  0.171   63      0
# 764     2   122    70    27     0  36.8  0.340   27      0
# 765     5   121    72    23   112  26.2  0.245   30      0
# 766     1   126    60     0     0  30.1  0.349   47      1
# 767     1    93    70    31     0  30.4  0.315   23      0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Histograms
#
# A fast way to get an idea of the distribution of each attribute is to look at histograms. Histograms group data into bins and provide you a count of the number of observations in each bin. From the shape of the bins you can quickly get a feeling for whether an attribute is Gaussian’, skewed or even has an exponential distribution. It can also help you see possible outliers.
#
# #### Exercise 1
#
# Plot histogram of each column and see if any data approximates a Gaussian distribution.
# Ref: [Normal or Gaussian Distribution](https://www.itl.nist.gov/div898/handbook/eda/section3/eda3661.htm)
#
# You could also use pandas histogram function too. Also, change `figsize` as necessary.

# %%
# YOUR CODE HERE
fig, axs = plt.subplots(3,3, figsize=(40,20))
for i in range(3):
    for j in range(3):
        axs[i][j].hist(data[names[3*i + j]], bins = 'auto')
        axs[i][j].set(xlabel="Value", ylabel="Frequency", title= "Histogram for " + names[3*i + j])
        axs[i][j].grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Density Plots
#
# Density plots are continuous graphs, just another way of getting a quick idea of the distribution of each attribute. The plots look like an abstracted histogram with a smooth curve drawn through the top of each bin, much like your eye tried to do with the histograms.
#
# #### Exercise 2
#
# Plot density plots of each column.

# %%
data.plot(kind="density", layout=(3,3), figsize=(20,10), legend=False,title=names, sharex=False, grid=True, subplots=True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Box and Whisker Plots (Boxplot)
#
# Boxplots summarize the distribution of each attribute, drawing a line for the median (middle value) and a box around the 25th and 75th percentiles (the middle 50% of the data). The whiskers give an idea of the spread of the data and dots outside of the whiskers show candidate outlier values (values that are 1.5 times greater than the size of spread of the middle 50% of the data).
#
# #### Exercise 3
#
# Plot Boxplots and see how many of the columns are affected by outliers.

# %%
# YOUR CODE HERE
fig, axs = plt.subplots(3,3, figsize=(40,20))
for i in range(3):
    for j in range(3):
        axs[i][j].boxplot(data[names[3*i + j]])
        axs[i][j].grid(alpha=0.5)
        axs[i][j].set_title(names[3*i+j])
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scatterplot Matrix
#
# A scatterplot shows the relationship between two variables as dots in two dimensions, one axis for each attribute. You can create a scatterplot for each pair of attributes in your data. Drawing all these scatterplots together is called a scatterplot matrix.
#
# Scatter plots are useful for spotting structured relationships between variables, like whether you could summarize the relationship between two variables with a line. Attributes with structured relationships may also be correlated and good candidates for removal from your dataset.
#
# #### Exercise 4
#
# Plot a scatter plot of pressure ('pres') and BMI ('mass') colored based on 'class' with size of each plot determined by plasma glucose concentration ('plas').
#
# ***Note: Only consider rows where pressure and mass are not zero***.

# %%
# YOUR CODE HERE
def colors(class_):
    if class_ ==0:
        return "red"
    return "blue"

new_data = data.loc[data["pres"]!=0].loc[data["mass"]!=0]
plt.figure(figsize=(20,10))
plt.scatter(new_data["pres"], new_data["mass"], s=new_data["plas"], c=list(map(colors, data["class"])))
plt.show()

# %% [markdown]
# ### Correlation Matrix Plot
# Correlation Matrix plot shows how related the changes are between two variables. If two variables change in the same direction they are positively correlated. If they change in opposite direction together, then they are negatively correlated. A plot of the correlation between each pair of attributes, called a correlation matrix, can provide an idea of which variables have a high correlation with each other.
#
# This is useful to know, because some machine learning algorithms like linear and logistic regression can have poor performance if there are highly correlated input variables in your data.
#
# #### Exercise 5
#
# Plot a Correlation matrix plot for the given data if you can find any correlation between the data, is the data symmetrical ?
#
# What is `class` most correlated with?
#
# See: [Pandas Correlation function](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.corr.html)

# %%
# YOUR CODE HERE
data.corr().style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col0 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col1 {
#             background-color:  #f4edf6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col2 {
#             background-color:  #f0eaf4;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col3 {
#             background-color:  #fbf3f9;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col4 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col5 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col6 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col7 {
#             background-color:  #4697c4;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow0_col8 {
#             background-color:  #e3e0ee;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col0 {
#             background-color:  #dddbec;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col1 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col2 {
#             background-color:  #eee8f3;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col3 {
#             background-color:  #e6e2ef;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col4 {
#             background-color:  #a5bddb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col5 {
#             background-color:  #d9d8ea;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col6 {
#             background-color:  #e3e0ee;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col7 {
#             background-color:  #b3c3de;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow1_col8 {
#             background-color:  #91b5d6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col0 {
#             background-color:  #dad9ea;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col1 {
#             background-color:  #f0eaf4;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col2 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col3 {
#             background-color:  #c4cbe3;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col4 {
#             background-color:  #e7e3f0;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col5 {
#             background-color:  #cacee5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col6 {
#             background-color:  #f4eef6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col7 {
#             background-color:  #b9c6e0;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow2_col8 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col0 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col1 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col2 {
#             background-color:  #e1dfed;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col3 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col4 {
#             background-color:  #7eadd1;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col5 {
#             background-color:  #a4bcda;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col6 {
#             background-color:  #d9d8ea;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col7 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow3_col8 {
#             background-color:  #fef6fa;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col0 {
#             background-color:  #fef6fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col1 {
#             background-color:  #c2cbe2;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col2 {
#             background-color:  #f8f1f8;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col3 {
#             background-color:  #76aad0;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col4 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col5 {
#             background-color:  #e0dded;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col6 {
#             background-color:  #d9d8ea;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col7 {
#             background-color:  #f5eff6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow4_col8 {
#             background-color:  #f5eef6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col0 {
#             background-color:  #f1ebf5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col1 {
#             background-color:  #e1dfed;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col2 {
#             background-color:  #d0d1e6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col3 {
#             background-color:  #86b0d3;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col4 {
#             background-color:  #d0d1e6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col5 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col6 {
#             background-color:  #e2dfee;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col7 {
#             background-color:  #eae6f1;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow5_col8 {
#             background-color:  #d2d2e7;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col0 {
#             background-color:  #f8f1f8;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col1 {
#             background-color:  #f2ecf5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col2 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col3 {
#             background-color:  #cacee5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col4 {
#             background-color:  #d2d3e7;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col5 {
#             background-color:  #ece7f2;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col6 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col7 {
#             background-color:  #ebe6f2;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow6_col8 {
#             background-color:  #eee8f3;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col0 {
#             background-color:  #4c99c5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col1 {
#             background-color:  #d8d7e9;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col2 {
#             background-color:  #dad9ea;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col3 {
#             background-color:  #fff7fb;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col4 {
#             background-color:  #fbf3f9;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col5 {
#             background-color:  #fdf5fa;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col6 {
#             background-color:  #f5eff6;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col7 {
#             background-color:  #023858;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow7_col8 {
#             background-color:  #dfddec;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow8_col0 {
#             background-color:  #c6cce3;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow8_col1 {
#             background-color:  #8eb3d5;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow8_col2 {
#             background-color:  #fbf4f9;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow8_col3 {
#             background-color:  #e2dfee;
#         }    #T_65bf9502_1f34_11e9_8c68_0a580a3005bbrow8_col4 {
#             bac
